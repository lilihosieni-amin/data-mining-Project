# %%
import matplotlib.pyplot as plt

# رسم نمودار برای ویژگی "gender"
plt.figure(figsize=(8, 6))
data["gender"].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.xlabel("gender")
plt.ylabel("count")
plt.xticks(rotation=45)
plt.savefig("/home/lili/Downloads/Telegram Desktop/gender_frequency_plot.png", bbox_inches='tight')
plt.show()

# رسم نمودار برای ویژگی "ever_married"
plt.figure(figsize=(8, 6))
data["ever_married"].value_counts().plot(kind='bar', color='yellow', edgecolor='black')
plt.xlabel("ever_married")
plt.ylabel("count")
plt.xticks(rotation=45)
plt.savefig("/home/lili/Downloads/Telegram Desktop/ever_married_frequency_plot.png", bbox_inches='tight')
plt.show()

# رسم نمودار برای ویژگی "work_type"
plt.figure(figsize=(8, 6))
data["work_type"].value_counts().plot(kind='bar', color='pink', edgecolor='black')
plt.xlabel("work type")
plt.ylabel("count")
plt.xticks(rotation=45)
plt.savefig("/home/lili/Downloads/Telegram Desktop/work_type_frequency_plot.png", bbox_inches='tight')
plt.show()

# رسم نمودار برای ویژگی "Residence_type"
plt.figure(figsize=(8, 6))
data["Residence_type"].value_counts().plot(kind='bar', color='orange', edgecolor='black')
plt.xlabel("Residence type")
plt.ylabel("count")
plt.xticks(rotation=45)
plt.savefig("/home/lili/Downloads/Telegram Desktop/Residence_type_frequency_plot.png", bbox_inches='tight')
plt.show()

# رسم نمودار برای ویژگی "smoking_status"
plt.figure(figsize=(8, 6))
data["smoking_status"].value_counts().plot(kind='bar', color='green', edgecolor='black')
plt.xlabel("smoking status")
plt.ylabel("count")
plt.xticks(rotation=45)
plt.savefig("/home/lili/Downloads/Telegram Desktop/smoking_status_frequency_plot.png", bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Selecting only numeric columns
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Calculating the correlation matrix for numeric features
correlation_matrix = numeric_data.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="YlGnBu", cbar=True, square=True)
plt.title("Heatmap")
plt.show()
